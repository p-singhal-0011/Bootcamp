# %% [markdown]
# ## Q1. Import the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Q2.import csv file Diwali Sales Data.csv

# %%
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %% [markdown]
# ## Q3. Find the shape of the data

# %%
df.shape
# Out:
# (11251, 15)

# %% [markdown]
# ## Q4. Fetch the first five rows of the dataset

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# ## Q5. Get the complete info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Q6. Drop unrelated/blank columns 'Status' and 'unnamed1'

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %% [markdown]
# ## Q7. Check for null values and find which columns have null values

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# ## Q8. Calculate the mean value of Age, Orders and Amount by using describe function

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ## Q9. Plot a bar chart for Gender and it's count

# %%
ax = sns.countplot(x='Gender', data=df)

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# ## Q10. Plot a bar chart for gender vs total amount

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(8, 6))
ax = sns.barplot(x='Gender', y='Amount', data=sales_gen, estimator='sum')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%d')

plt.show()

# %% [markdown]
# ## Q11. Plot the countplot for Age Group with hue and Gender

# %%
ax = sns.countplot(data=df, x='Age Group', hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# ## Q12. Draw the plot for total number of orders from top 10 states

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(data = sales_state, x = 'State',y= 'Orders')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# ## Q13.Draw the plot to plot total amount/sales from top 10 states

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(data = sales_state, x = 'State',y= 'Amount')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%d')

plt.show()

# %% [markdown]
# ## Q14. Draw the plot to show the marital status

# %%
ax = sns.countplot(data=df, x='Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# ## Q15. Draw the plot to show the top 10 occupations

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
ax = sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%d')

plt.show()

# %% [markdown]
# ## Q16. Draw the countplot to print the top 10 categories

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
ax = sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')

for bars in ax.containers:
    ax.bar_label(bars, fmt='%d')

plt.show()

# %% [markdown]
# ## Q17. What is the prodct ID of the top 10 most sold products.

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
ax = sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# ## Q18. What conclusion you can draw from the above visualizations.

# %% [markdown]
# ### From the visualizations, we can draw the following conclusions:
#
# ### 1. **Gender Distribution:** The sales are dominated by females, both in terms of the count of buyers and the total amount spent.
#
# ### 2. **Age Group vs. Gender:** The age group 26-35 is the most prominent buyer group. Within this age group, females are significantly more numerous buyers than males.
#
# ### 3. **Top States for Orders and Sales:** Uttar Pradesh, Maharashtra, and Karnataka are the top states contributing to both the highest number of orders and the highest total sales amount.
#
# ### 4. **Marital Status:** The majority of buyers are married individuals.
#
# ### 5. **Top Occupations:** Individuals in IT Sector, Healthcare, and Aviation occupations contribute the most to the total sales amount.
#
# ### 6. **Top Product Categories:** Clothing, Food, and Electronics & Gadgets are the product categories with the highest sales amounts.
#
# ### 7. **Top Selling Products:** We can identify the top 10 individual product IDs based on the number of orders. These are the most popular items among the customers.
#
# ### Overall, the data suggests that during the Diwali season, married women aged 26-35 from states like Uttar Pradesh, Maharashtra, and Karnataka, working in the IT sector, healthcare, and aviation, are the primary customers, showing a preference for clothing, food, and electronics. The visualizations provide a clear picture of the customer demographics and popular products, which can be valuable for targeted marketing and inventory management.
