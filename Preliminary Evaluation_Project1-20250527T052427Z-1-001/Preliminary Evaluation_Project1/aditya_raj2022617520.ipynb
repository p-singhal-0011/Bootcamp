# %% [markdown]
# <a href="https://colab.research.google.com/github/rj-adity/BOOTCAMP_2024-SHARDA-/blob/main/EDA_Proejct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Q1. Import the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Q2.import csv file Diwali Sales Data.csv

# %%
df=pd.read_csv('/content/Diwali Sales Data.csv',encoding='unicode_escape')
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# ## Q3. Find the shape of the data

# %%
df.shape
# Out:
# (11251, 15)

# %% [markdown]
# ## Q4. Fetch the first five rows of the dataset

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# ## Q5. Get the complete info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Q6. Drop unrelated/blank columns 'Status' and 'unnamed1'

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %% [markdown]
# ## Q7. Check for null values and find which columns have null values

# %%
df.isna()
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# ## Q8. Calculate the mean value of Age, Orders and Amount by using describe function

# %%
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ## Q9. Plot a bar chart for Gender and it's count

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## Q10. Plot a bar chart for gender vs total amount

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Gender',y='Amount',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# ## Q11. Plot the countplot for Age Group with hue and Gender

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Age Group',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %% [markdown]
# ## Q12. Draw the plot for total number of orders from top 10 states

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='State',data=df,order=df['State'].value_counts().head(10).index)
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# ## Q13.Draw the plot to plot total amount/sales from top 10 states

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x='State',y='Amount',data=df,order=df['State'].value_counts().head(10).index)
plt.xticks(rotation=90)
plt.tight_layout()
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

# %% [markdown]
# ## Q14. Draw the plot to show the marital status

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# ## Q15. Draw the plot to show the top 10 occupations

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Occupation',y='Amount',data=df,order=df['Occupation'].value_counts().head(10).index)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# ## Q16. Draw the countplot to print the top 10 categories

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Product_Category',data=df,order=df['Product_Category'].value_counts().head(10).index)
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# ## Q17. What is the prodct ID of the top 10 most sold products.

# %%
plt.figure(figsize=(12, 6))
top_10_product_ids = df['Product_ID'].value_counts().head(10)
top_10_product_ids.plot(kind='bar')
plt.title('Top 10 Most Sold Products by Product ID')
plt.xlabel('Product ID')
plt.ylabel('Number of Sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q18. What conclusion you can draw from the above visualizations.

# %% [markdown]
# Gender and Sales (Q9 & Q10):
#
# Q9 (Count of Gender): This plot shows the absolute number of males and females in your dataset. A detailed conclusion here would be stating which gender has a higher representation in your customer base. For instance, "Based on the bar chart, the dataset contains a significantly higher number of [Gender] customers compared to [Other Gender]."
# Q10 (Gender vs. Total Amount): This plot shows the total sales amount contributed by each gender. A detailed conclusion would be about which gender contributes more to revenue. For example, "Despite the possible difference in customer numbers shown in the previous plot, the 'Gender vs. Total Amount' bar chart indicates that [Gender] contributes a substantially larger amount to the total sales than [Other Gender]."
# Age Group and Gender (Q11): This countplot breaks down the number of customers by both Age Group and Gender.
#
# A detailed conclusion would be to identify which age groups have the highest concentration of customers overall, and then within those age groups, which gender is more prevalent. For example, "The countplot reveals that the age group [Age Group] has the highest number of customers. Within this age group, [Gender] customers are more numerous than [Other Gender] customers." You could also identify if there are any age groups where the gender distribution is more balanced or skewed in the opposite direction.
# Top States for Orders and Sales (Q12 & Q13):
#
# Q12 (Top 10 States by Orders): This plot shows the count of orders originating from the top 10 states. A detailed conclusion would list the top states and comment on the relative volume of orders. For instance, "The bar chart clearly identifies [State 1], [State 2], and [State 3] as the top three states with the highest number of orders. There is a noticeable drop in order volume after the top few states."
# Q13 (Top 10 States by Total Amount): This plot shows the total sales amount from the top 10 states. A detailed conclusion would compare the revenue generated by these states. You can also compare this to the previous plot: "When examining the total sales amount, [State A], [State B], and [State C] are the top revenue-generating states. It is interesting to note that while some states appear in both the top states for orders and sales, there might be some variation, suggesting differences in average order value across states."
# Marital Status (Q14): This countplot shows the number of customers by their marital status.
#
# A detailed conclusion would state which marital status is most frequent among your customers. For example, "The countplot for Marital Status indicates that the majority of customers in this dataset are [Marital Status]. The other marital statuses are significantly less represented."
# Top 10 Occupations (Q15): This bar plot shows the total sales amount generated by customers in the top 10 occupations.
#
# A detailed conclusion would identify which occupations contribute the most to sales and comment on the differences in sales contributions across occupations. For example, "The bar plot highlights [Occupation 1], [Occupation 2], and [Occupation 3] as the top three occupations in terms of sales contribution. This suggests that individuals in these professions are key customer segments."
# Top 10 Product Categories (Q16): This countplot shows the number of sales for the top 10 product categories.
#
# A detailed conclusion would list the most popular product categories based on the number of times they were sold. For example, "The countplot of Product Category reveals that [Category 1], [Category 2], and [Category 3] are the most frequently sold product categories. This indicates high customer demand for products in these areas."
# Top 10 Most Sold Products by Product ID (Q17): This plot shows the number of sales for the top 10 specific products based on their Product ID.
#
# A detailed conclusion would identify the specific product IDs that are the best sellers. For instance, "The bar plot for Top 10 Most Sold Products clearly shows that products with IDs [Product ID 1], [Product ID 2], and [Product ID 3] have the highest sales volume. These are the star products in the dataset."
# By analyzing the visual patterns and values in each of these plots, you can draw these more specific and detailed conclusions about your Diwali sales data.
